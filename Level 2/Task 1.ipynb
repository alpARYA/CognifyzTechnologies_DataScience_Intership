# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/itsme/Onedrive/Desktop/CognifyzTechnologies_DataScience_Intership/Dataset .csv")

# %%
print("Unique values in 'Has Table booking':", df['Has Table booking'].unique())
print("Unique values in 'Has Online delivery':", df['Has Online delivery'].unique())
# Out:
# Unique values in 'Has Table booking': ['Yes' 'No']
# Unique values in 'Has Online delivery': ['No' 'Yes']

# %%
booking_delivery_ct = pd.crosstab(df['Has Table booking'], df['Has Online delivery'])
print("\nCrosstab of Table Booking vs Online Delivery:")
print(booking_delivery_ct)
# Out:
# Crosstab of Table Booking vs Online Delivery:
# Has Online delivery    No   Yes
# Has Table booking
# No                   6377  2016
# Yes                   723   435

# %%
booking_delivery_ct.plot(kind='bar', stacked=False, colormap='Set2', figsize=(8, 6))
plt.title("Table Booking vs Online Delivery")
plt.xlabel("Has Table Booking")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.legend(title="Has Online Delivery")
plt.tight_layout()
plt.show()

# %%
booking_delivery_pct = booking_delivery_ct.div(booking_delivery_ct.sum(axis=1), axis=0) * 100
print("\nPercentage comparison:")
print(booking_delivery_pct.round(2))
# Out:
# Percentage comparison:
# Has Online delivery     No    Yes
# Has Table booking
# No                   75.98  24.02
# Yes                  62.44  37.56
